# %% [markdown]
# Random table generator
# - Take in CSV files (maybe excel)
# - CSV file can have any number of columns, each column has a header/title
# - Column can have different length
#
# - need to make an example csv file
# - happy for it to run on jupyter notebook

# %%
import pandas as pd

# %%
# function to load csv file

example_table = pd.read_csv('../data/example-table.csv')

# %%
example_table
# Out:
#   Weather  Time of Day  Environment  Environmental Hazard           NPCs
# 0   Sunny    Midnight       Coastal               Volcano   Cartographer
# 1  Stormy         Dawn       Desert             Landslide  Meteorologist
# 2   Snowy         Noon          NaN            Earthquake      Geologist
# 3     NaN     Twilight          NaN                   NaN         Wizard
# 4     NaN          NaN          NaN                   NaN         Cleric
# 5     NaN          NaN          NaN                   NaN       Merchant

# %%
example_table.columns = example_table.columns.str.strip()
example_table.columns
# Out:
# Index(['Weather', 'Time of Day', 'Environment', 'Environmental Hazard',
#        'NPCs'],
#       dtype='str')

# %%
example_table['Weather']
# Out:
# 0     Sunny
# 1    Stormy
# 2     Snowy
# 3       NaN
# 4       NaN
# 5       NaN
# Name: Weather, dtype: str

# %%
def load_table(filepath):
    example_table = pd.read_csv(filepath)
    example_table.columns = example_table.columns.str.strip()
    return example_table

# %%
# function to remind what categories are available

# %%
# function that given a category will randomly select and print it
